# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#from fsspec.registry import known_implementations
#from fs import open_fs
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
# from tensorflow.keras.utils import to_categorical

# %%
spotify_df = pd.read_csv('../Resources/tracks.csv')
spotify_df.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1922-02-22         0.645  0.4450    0   -13.338     1       0.4510
# 1   1922-06-01         0.695  0.2630    0   -22.136     1       0.9570
# 2   1922-03-21         0.434  0.1770    1   -21.180     1       0.0512
# 3   1922-03-21         0.321  0.0946    7   -27.961     1       0.0504
# 4         1922         0.402  0.1580    3   -16.900     0       0.0390
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.674            0.7440     0.151    0.127  104.851               3
# 1         0.797            0.0000     0.148    0.655  102.009               1
# 2         0.994            0.0218     0.212    0.457  130.418               5
# 3         0.995            0.9180     0.104    0.397  169.980               3
# 4         0.989            0.1300     0.311    0.196  103.220               4

# %%
#  Remove features that create noise and result in improved model
removed_df = spotify_df.drop(columns=['id', 'duration_ms', 'id_artists', 'key', 'mode', 'time_signature','valence', 'tempo','liveness'])
# Drop the null columns where all values are null
spotify_df = removed_df.dropna(axis='columns', how='all')
# Drop the null rows
cleaned_df = removed_df.dropna()
cleaned_df.describe()
# Out:
#           popularity       explicit   danceability         energy  \
# count  586601.000000  586601.000000  586601.000000  586601.000000
# mean       27.573212       0.044091       0.563612       0.542071
# std        18.369417       0.205298       0.166101       0.251910
# min         0.000000       0.000000       0.000000       0.000000
# 25%        13.000000       0.000000       0.453000       0.343000
# 50%        27.000000       0.000000       0.577000       0.549000
# 75%        41.000000       0.000000       0.686000       0.748000
# max       100.000000       1.000000       0.991000       1.000000
#
#             loudness    speechiness   acousticness  instrumentalness
# count  586601.000000  586601.000000  586601.000000     586601.000000
# mean      -10.205789       0.104870       0.449803          0.113425
# std         5.089422       0.179902       0.348812          0.266843
# min       -60.000000       0.000000       0.000000          0.000000
# 25%       -12.891000       0.034000       0.096900          0.000000
# 50%        -9.242000       0.044300       0.422000          0.000024
# 75%        -6.481000       0.076300       0.784000          0.009550
# max         5.376000       0.971000       0.996000          1.000000

# %%
#Review the correlation of popularity to the other attributes
#popularity is our dependent variable for regression (x-value)
pop_corr = cleaned_df.corr()["popularity"]

# %%
#This provides the r-value of correlation
pop_corr
# Out:
# popularity          1.000000
# explicit            0.211749
# danceability        0.186878
# energy              0.302178
# loudness            0.327001
# speechiness        -0.047415
# acousticness       -0.370723
# instrumentalness   -0.236403
# Name: popularity, dtype: float64

# %%
#This computes the r-squared value. 
#note: in this example, the higher r-squared value would indicate that the higher the acousticness level, the less popular the song is
pop_r2 = pop_corr*pop_corr

# %%
pop_r2
# Out:
# popularity          1.000000
# explicit            0.044838
# danceability        0.034923
# energy              0.091312
# loudness            0.106930
# speechiness         0.002248
# acousticness        0.137436
# instrumentalness    0.055886
# Name: popularity, dtype: float64

# %%
#Temporarily removed popularity column to visualize correlations between other variables easier.  Looking to see if any of the variables is a predictor of another variable (highly correlated).
remove_pop = cleaned_df.drop(columns=['popularity'])
remove_pop.head()
# Out:
#                                   name  explicit              artists  \
# 0                                Carve         0              ['Uli']
# 1  Capítulo 2.16 - Banquero Anarquista         0  ['Fernando Pessoa']
# 2   Vivo para Quererte - Remasterizado         0  ['Ignacio Corsini']
# 3        El Prisionero - Remasterizado         0  ['Ignacio Corsini']
# 4                  Lady of the Evening         0      ['Dick Haymes']
#
#   release_date  danceability  energy  loudness  speechiness  acousticness  \
# 0   1922-02-22         0.645  0.4450   -13.338       0.4510         0.674
# 1   1922-06-01         0.695  0.2630   -22.136       0.9570         0.797
# 2   1922-03-21         0.434  0.1770   -21.180       0.0512         0.994
# 3   1922-03-21         0.321  0.0946   -27.961       0.0504         0.995
# 4         1922         0.402  0.1580   -16.900       0.0390         0.989
#
#    instrumentalness
# 0            0.7440
# 1            0.0000
# 2            0.0218
# 3            0.9180
# 4            0.1300

# %%
#Testing different correlation methods to see which one offers the best analysis
var_corr1 = remove_pop.corr(method='kendall')
var_corr1
# Out:
#                   explicit  danceability    energy  loudness  speechiness  \
# explicit          1.000000      0.122225  0.101236  0.122786     0.173292
# danceability      0.122225      1.000000  0.145264  0.130604     0.151689
# energy            0.101236      0.145264  1.000000  0.577148     0.107438
# loudness          0.122786      0.130604  0.577148  1.000000     0.012216
# speechiness       0.173292      0.151689  0.107438  0.012216     1.000000
# acousticness     -0.117415     -0.137830 -0.525178 -0.367519    -0.020570
# instrumentalness -0.086080     -0.153380 -0.086980 -0.183678    -0.075904
#
#                   acousticness  instrumentalness
# explicit             -0.117415         -0.086080
# danceability         -0.137830         -0.153380
# energy               -0.525178         -0.086980
# loudness             -0.367519         -0.183678
# speechiness          -0.020570         -0.075904
# acousticness          1.000000          0.073397
# instrumentalness      0.073397          1.000000

# %%
#Testing different correlation methods to see which one offers the best analysis
var_corr2 = remove_pop.corr(method='pearson')
var_corr2
# Out:
#                   explicit  danceability    energy  loudness  speechiness  \
# explicit          1.000000      0.150216  0.123060  0.134598     0.102251
# danceability      0.150216      1.000000  0.241464  0.251394     0.199291
# energy            0.123060      0.241464  1.000000  0.764744    -0.053560
# loudness          0.134598      0.251394  0.764744  1.000000    -0.167140
# speechiness       0.102251      0.199291 -0.053560 -0.167140     1.000000
# acousticness     -0.149001     -0.242838 -0.715366 -0.519423     0.069121
# instrumentalness -0.067510     -0.225831 -0.195727 -0.329255    -0.102425
#
#                   acousticness  instrumentalness
# explicit             -0.149001         -0.067510
# danceability         -0.242838         -0.225831
# energy               -0.715366         -0.195727
# loudness             -0.519423         -0.329255
# speechiness           0.069121         -0.102425
# acousticness          1.000000          0.204312
# instrumentalness      0.204312          1.000000

# %%
#Testing different correlation methods to see which one offers the best analysis
var_corr3 = remove_pop.corr(method='spearman')
var_corr3
# Out:
#                   explicit  danceability    energy  loudness  speechiness  \
# explicit          1.000000      0.149568  0.123922  0.150376     0.212058
# danceability      0.149568      1.000000  0.216573  0.193832     0.234170
# energy            0.123922      0.216573  1.000000  0.771030     0.167386
# loudness          0.150376      0.193832  0.771030  1.000000     0.021027
# speechiness       0.212058      0.234170  0.167386  0.021027     1.000000
# acousticness     -0.143744     -0.202743 -0.718286 -0.528900    -0.037929
# instrumentalness -0.100946     -0.219107 -0.125822 -0.258086    -0.111726
#
#                   acousticness  instrumentalness
# explicit             -0.143744         -0.100946
# danceability         -0.202743         -0.219107
# energy               -0.718286         -0.125822
# loudness             -0.528900         -0.258086
# speechiness          -0.037929         -0.111726
# acousticness          1.000000          0.110663
# instrumentalness      0.110663          1.000000

# %%
y = cleaned_df.loc[:, 'energy']
X = cleaned_df.drop(['name','artists','release_date','energy'],axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1000)

# %%
lin_model = LinearRegression()
lin_model.fit(X_test, y_test)
lin_acc = lin_model.score(X_test, y_test)
print(lin_acc)
# Out:
# 0.7376768640192175

# %%
print(lin_model.score(X_train,y_train))
# Out:
# 0.7364231490581258

# %%
predictions = lin_model.predict(X)
# Plot Residuals
plt.scatter(predictions, predictions - y)
plt.hlines(y=0, xmin=predictions.min(), xmax=predictions.max())
plt.show()

# %%
y = cleaned_df.loc[:, 'danceability']
X = cleaned_df.drop(['name','artists','release_date','danceability'],axis=1)


X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=100)

# %%
lin_model = LinearRegression()
lin_model.fit(X_test, y_test)
lin_acc = lin_model.score(X_test, y_test)
print(lin_acc)
# Out:
# 0.1626054803608048

# %%
y = cleaned_df.loc[:, 'explicit']
X = cleaned_df.drop(['name','artists','release_date','explicit'],axis=1)


X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=100)

# %%
lin_model = LinearRegression()
lin_model.fit(X_test, y_test)
lin_acc = lin_model.score(X_test, y_test)
print(lin_acc)
# Out:
# 0.07277765105008416
